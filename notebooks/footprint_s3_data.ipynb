# %% [markdown]
# # Footprint rasters on s3
#
# `LVIS` at ORNL DAAC AWS buckets
# `TerraPulse` at their AWS buckets
# `ESA Worldcover`/`Copernicus GLODEM`/`META Forest CHM` at Open Registry AWS buckets
#
# Paul Montesano, PhD
#
# #### Note:
#  - to return the spatial extent of s3 raster paths
#  - needed for `build_stack`

# %%
from mpl_toolkits.basemap import Basemap

# %%
# !pip install -U contextily

# %%
import s3fs
import os
import boto3
import pandas as pd
import geopandas as gpd
import sys
sys.path.append('/projects/code/icesat2_boreal/lib')
sys.path.append('/projects/code/geoscitools')
import footprintlib
import maplib
import CovariateUtils

import rasterio
import contextily as ctx
import requests
import glob

import rasterio as rio
from rasterio.windows import Window
# Out:
# /opt/conda/envs/pangeo/lib/python3.10/site-packages/osgeo/osr.py:385: FutureWarning: Neither osr.UseExceptions() nor osr.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(

# %% [markdown]
# ## Access to TerraPulse s3 bucket

# %%
dict_list = [
    # TerraPulse unclipped annual boreal TCC
    {'location':'s3',  #'local' or 's3'
     'data_dir': "s3://terrapulse-pub-data",
     's3_url_prefix': None,
     'data_source': 'terrapulse-pub-data',
     'image_type': 'boreal-tcc-unclipped', 
     'search_tail_string': '/data/**/*y2019_dat.tif', # the year here can vary between 1984-2020; tiles should be exactly the same
     'search_link_string': '',
     'DO_DATAMASK': False,
     'GET_ONLY_DATASETMASK': True,
     'out_footprint_dir': '/efs/projects/forest_height',
     'footprint_name_SPLIT_CHAR': '_',
     'footprint_name_SPLIT_POS': 0,
     'aws_credential_fn': '/efs/pmontesa/credentials'
    },
    {'location':'s3',  #'local' or 's3'
     'data_dir': "s3://terrapulse-pub-data/boreal-forest-data",
     's3_url_prefix': None,
     'data_source': 'terrapulse-pub-data',
     'image_type': 'forest_loss',#'tcc_pvalue',#'tcc_slope', #'tcc_2020', tcc_pvalue, forest_age, forest_loss
     'search_tail_string': '/**/*dat.tif',
     'search_link_string': '',
     'DO_DATAMASK': False,
     'GET_ONLY_DATASETMASK': True,
     'out_footprint_dir': '/efs/projects/forest_height',
     'footprint_name_SPLIT_CHAR': '_',
     'footprint_name_SPLIT_POS': 0,
     'aws_credential_fn': '/efs/pmontesa/credentials'
    }
]

# %%
s3 = s3fs.S3FileSystem(anon=True)

# %%
s3.ls('s3://terrapulse-pub-data')
# Out:
# ['terrapulse-pub-data/boreal-forest-data',
#  'terrapulse-pub-data/boreal-tcc-unclipped',
#  'terrapulse-pub-data/index.html',
#  'terrapulse-pub-data/kml',
#  'terrapulse-pub-data/land']

# %%
s3.ls('s3://terrapulse-pub-data/boreal-forest-data')
# Out:
# ['terrapulse-pub-data/boreal-forest-data/datasets_readme.pdf',
#  'terrapulse-pub-data/boreal-forest-data/forest_age',
#  'terrapulse-pub-data/boreal-forest-data/forest_loss',
#  'terrapulse-pub-data/boreal-forest-data/tcc_2020',
#  'terrapulse-pub-data/boreal-forest-data/tcc_pvalue',
#  'terrapulse-pub-data/boreal-forest-data/tcc_slope']

# %%
fn_list_main = s3.glob('s3://terrapulse-pub-data/boreal-tcc-unclipped/data/**/*.tif')

# %%
fn_list = s3.glob('s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/**/*dat.tif')
# Out:
# KeyboardInterrupt

# %%
fn_list[-10:]

# %% [markdown]
# ### Set TCC year to access

# %%
YEAR_TCC = 2020

# %%
TerraPulse_AWS_DATA_DICT_LIST = [
                    {
                'AWS_SESSION':    s3fs.S3FileSystem(anon=True),
                'REFERENCE':     'https://doi.org/10.3334/ORNLDAAC/2012',
                'BUCKET' :       'terrapulse-pub-data/boreal-forest-data', 
                'FILES_LIST':     None,
                'RASTER_BUCKET': 'terrapulse-pub-data/boreal-forest-data/forest_age',
                'SEARCHKEY':     'age',
                'SEARCHEXT':     '.tif',
                'RASTER_LIST':    None
                },
                {
                'AWS_SESSION':    s3fs.S3FileSystem(anon=True),
                'REFERENCE':     '',
                'BUCKET' :       'terrapulse-pub-data/boreal-forest-data', 
                'FILES_LIST':     None,
                'RASTER_BUCKET': 'terrapulse-pub-data/boreal-forest-data/tcc_slope',
                'SEARCHKEY':     '', # 
                'SEARCHEXT':     '.tif',
                'RASTER_LIST':    None
                },
                {
                'AWS_SESSION':    s3fs.S3FileSystem(anon=True),
                'REFERENCE':     '',
                'BUCKET' :       'terrapulse-pub-data/boreal-forest-data', 
                'FILES_LIST':     None,
                'RASTER_BUCKET': 'terrapulse-pub-data/boreal-forest-data/tcc_pvalue',
                'SEARCHKEY':     '', # 
                'SEARCHEXT':     '.tif',
                'RASTER_LIST':    None
                },
                {
                'AWS_SESSION':    s3fs.S3FileSystem(anon=True),
                'REFERENCE':     '',
                'BUCKET' :       'terrapulse-pub-data/boreal-tcc-unclipped', 
                'FILES_LIST':     None,
                'RASTER_BUCKET': 'terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/**/',
                'SEARCHKEY':     f'*y{YEAR_TCC}._dat', # 
                'SEARCHEXT':     '.tif',
                'RASTER_LIST':    None
                }
]

# %% [markdown]
# ## Access to EarthData s3 bucket
#
# https://github.com/nasa/EMIT-Data-Resources/blob/main/python/how-tos/How_to_Direct_S3_Access.ipynb

# %%
s3_cred_endpoint = {
    'podaac':'https://archive.podaac.earthdata.nasa.gov/s3credentials',
    'gesdisc': 'https://data.gesdisc.earthdata.nasa.gov/s3credentials',
    'lpdaac':'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials',
    'ornldaac': 'https://data.ornldaac.earthdata.nasa.gov/s3credentials',
    'ghrcdaac': 'https://data.ghrc.earthdata.nasa.gov/s3credentials'
}

# %%
# Define Function 
def get_temp_creds(provider):
    return requests.get(s3_cred_endpoint[provider]).json()

# %% [markdown]
# ### Datasets at EarthDataCloud
#  - LVIS Gridded: `C2264350397-ORNL_CLOUD` https://cmr.earthdata.nasa.gov/search/concepts/C2264350397-ORNL_CLOUD.html

# %%
# Get Credentials
temp_creds_req = get_temp_creds('ornldaac')

# Pass Authentication to s3fs
s3_ornl = s3fs.S3FileSystem(anon=False, key=temp_creds_req['accessKeyId'], secret=temp_creds_req['secretAccessKey'], token=temp_creds_req['sessionToken'])

ORNL_AWS_DATA_DICT_LIST = [
                    {
                'AWS_SESSION':    s3_ornl,
                'REFERENCE':     'https://daac.ornl.gov/cgi-bin/dataset_lister.pl?p=34',
                'BUCKET' :       'ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure', 
                'FILES_LIST':     None,
                'RASTER_BUCKET': 'ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data',
                'SEARCHKEY':     '*RH098_mean_30m',
                'SEARCHEXT':     '.tif',
                'RASTER_LIST':    None
                },
                {
                'AWS_SESSION':    s3_ornl,
                'REFERENCE':     'https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=2296',
                'BUCKET' :       'ornl-cumulus-prod-protected/above/DeciduousFractionl_CanopyCover', 
                'FILES_LIST':     None,
                'RASTER_BUCKET': 'ornl-cumulus-prod-protected/above/DeciduousFractionl_CanopyCover/data',
                'SEARCHKEY':     'deciduousfraction_2015_prediction', #  companion 'uncertainty.tif' and 'prediction.tif' for tcc and decid fraction for 5 epochs
                'SEARCHEXT':     '.tif',
                'RASTER_LIST':    None
                }
]

# %%
s3.glob('s3://'+ORNL_AWS_DATA_DICT_LIST[1]['RASTER_BUCKET'])
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/s3fs/core.py:113, in _error_wrapper(func, args, kwargs, retries)
#     112 try:
# --> 113     return await func(*args, **kwargs)
#     114 except S3_RETRYABLE_ERRORS as e:
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/aiobotocore/client.py:408, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     407     error_class = self.exceptions.from_code(error_code)
# --> 408     raise error_class(parsed_response, operation_name)
#     409 else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 s3.glob('s3://'+ORNL_AWS_DATA_DICT_LIST[1]['RASTER_BUCKET'])
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/s3fs/core.py:785, in S3FileSystem._glob(self, path, **kwargs)
#     783 if path.startswith("*"):
#     784     raise ValueError("Cannot traverse all of S3")
# --> 785 return await super()._glob(path, **kwargs)
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/fsspec/asyn.py:763, in AsyncFileSystem._glob(self, path, maxdepth, **kwargs)
#     760 detail = kwargs.pop("detail", False)
#     762 if not has_magic(path):
# --> 763     if await self._exists(path, **kwargs):
#     764         if not detail:
#     765             return [path]
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/s3fs/core.py:1035, in S3FileSystem._exists(self, path)
#    1032     return exists_in_cache
#    1034 try:
# -> 1035     await self._info(path, bucket, key, version_id=version_id)
#    1036     return True
#    1037 except FileNotFoundError:
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/s3fs/core.py:1302, in S3FileSystem._info(self, path, bucket, key, refresh, version_id)
#    1300 if key:
#    1301     try:
# -> 1302         out = await self._call_s3(
#    1303             "head_object",
#    1304             self.kwargs,
#    1305             Bucket=bucket,
#    1306             Key=key,
#    1307             **version_id_kw(version_id),
#    1308             **self.req_kw,
#    1309         )
#    1310         return {
#    1311             "ETag": out.get("ETag", ""),
#    1312             "LastModified": out.get("LastModified", ""),
#    (...)
#    1318             "ContentType": out.get("ContentType"),
#    1319         }
#    1320     except FileNotFoundError:
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/s3fs/core.py:348, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     346 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     347 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 348 return await _error_wrapper(
#     349     method, kwargs=additional_kwargs, retries=self.retries
#     350 )
#
# File /opt/conda/envs/pangeo/lib/python3.10/site-packages/s3fs/core.py:140, in _error_wrapper(func, args, kwargs, retries)
#     138         err = e
#     139 err = translate_boto_error(err)
# --> 140 raise err
#
# PermissionError: Forbidden

# %% [markdown]
# ### Access to AWS Open Data Registry s3 bucket
# https://gist.github.com/wildintellect/151c80e291eddd249b7e171daa291c37
#
# Open datasets on AWS
# * https://registry.opendata.aws/esa-worldcover/
# * https://registry.opendata.aws/copernicus-dem/

# %% [markdown]
# #### Find dataset files within their buckets
# Put results of search into dictionaries

# %%
# Pass Authentication to s3fs
s3_anon = s3 = s3fs.S3FileSystem(anon=True)

OPEN_AWS_DATA_DICT_LIST = [
                    {
                'AWS_SESSION': s3_anon,
                'REFERENCE': 'https://registry.opendata.aws/dataforgood-fb-forests/',
                'BUCKET' : 'dataforgood-fb-data/forests/v1/alsgedi_global_v6_float',
                'FILES_LIST': None,
                'RASTER_BUCKET': 'dataforgood-fb-data/forests/v1/alsgedi_global_v6_float/chm/',
                'SEARCHKEY': '',
                'SEARCHEXT':'.tif',
                'RASTER_LIST': None
                },
                    {
                'AWS_SESSION': s3_anon,
                'REFERENCE': 'https://registry.opendata.aws/esa-worldcover/',
                'BUCKET' : 'esa-worldcover',
                'FILES_LIST': None,
                'RASTER_BUCKET': 'esa-worldcover/v200/2021/*/',
                'SEARCHKEY': '',
                'SEARCHEXT':'.tif',
                'RASTER_LIST': None
                },
    # Need to fix how s3.glob() is done on this dataset - takes forever for 25450 files nested in their own dirs
                # {
                # 'AWS_SESSION': s3_anon,
                # 'REFERENCE': 'https://registry.opendata.aws/copernicus-dem/',
                # 'BUCKET' : 'copernicus-dem-30m', 
                # 'FILES_LIST': None,
                # 'RASTER_BUCKET': 'copernicus-dem-30m/Copernicus_DSM_COG*/',
                # 'SEARCHKEY': 'Copernicus_DSM_COG*.tif',
                # 'RASTER_LIST': None
                # },

            ]

# %% [markdown]
# ## Loop over EarthData + Open Data Registry Data Dictionary List
#  - print # of files
#  - created `UPDATED_AWS_DATA_DICT_LIST` that has the FULL set of rasters returned from your search

# %%
# %%time

UPDATED_AWS_DATA_DICT_LIST = []

#for idx, d in enumerate(OPEN_AWS_DATA_DICT_LIST + ORNL_AWS_DATA_DICT_LIST):
#for idx, d in enumerate(OPEN_AWS_DATA_DICT_LIST[0:1]):
for idx, d in enumerate(ORNL_AWS_DATA_DICT_LIST[0:1]):  
#for idx, d in enumerate(TerraPulse_AWS_DATA_DICT_LIST[-1:]):
    
    # Get dataset-specific s3 session
    s3 = d['AWS_SESSION']
    
    bucket = d['BUCKET']
    searchkey = d['SEARCHKEY'] 
    searchext = d['SEARCHEXT']
    
    print(f"AWS dataset {idx+1:02} main bucket: {bucket} from {d['REFERENCE']}")
    
    print(f"# of files in {bucket}: {len(s3.glob(bucket + '/*')) }")
    
    # Update dict with a list of all files
    d.update( {'FILES_LIST': [i.replace(bucket, 's3://'+bucket) for i in s3.glob(os.path.join(bucket + '/*'))] })
    
    # Update dict with a list of all raster files if raster are in a separate bucket
    if not d['RASTER_BUCKET'] == bucket:
        bucket = d['RASTER_BUCKET']
    print(os.path.join(bucket, f'{searchkey}*{searchext}'))
    s3_f_list = s3.glob(os.path.join(bucket, f'{searchkey}*{searchext}') )
    
    # Update dict with a list of all files
    d.update( {'RASTER_LIST': [i.replace(bucket, 's3://'+bucket) for i in s3_f_list] })
    UPDATED_AWS_DATA_DICT_LIST.append(d)
    
    print(f"# of raster files in {d['RASTER_BUCKET']}: {len( d['RASTER_LIST'] )}")
    
    n=20
    print(f'Showing first {n}...')
    [print(file) for file in s3_f_list[0:n]]
    print('\n')
# Out:
# AWS dataset 01 main bucket: ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure from https://daac.ornl.gov/cgi-bin/dataset_lister.pl?p=34
# # of files in ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure: 1
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/*RH098_mean_30m*.tif
# # of raster files in ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data: 3579
# Showing first 20...
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_056233_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_056593_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_057198_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_057748_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_058064_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_058321_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_058625_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_058822_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_059030_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_059217_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_059391_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_060114_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_060453_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_060681_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_061014_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_061571_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_061677_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_061846_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_061984_RH098_mean_30m.tif
# ornl-cumulus-prod-protected/above/ABoVE_LVIS_VegetationStructure/data/LVISF3_ABoVE2017_0629_R1803_062193_RH098_mean_30m.tif
#
#
# CPU times: user 18.2 s, sys: 194 ms, total: 18.4 s
# Wall time: 32 s

# %% [markdown]
# ## Footprint the s3 data - add `s3_path`

# %%
import importlib
importlib.reload(footprintlib)
# Out:
# <module 'footprintlib' from '/projects/code/geoscitools/footprintlib.py'>

# %%
AWS_DATA_DICT = UPDATED_AWS_DATA_DICT_LIST[0]
s3 = AWS_DATA_DICT['AWS_SESSION']
#AWS_DATA_DICT

# %%
# %%time 
outprint_fn = os.path.join('/projects/my-public-bucket/databank/footprints', 
                           f"footprint_{os.path.basename(AWS_DATA_DICT['BUCKET'])}_{AWS_DATA_DICT['SEARCHKEY'].replace('*','')}.gpkg")

f_gdf_lst = [footprintlib.raster_footprint(s3.open(r_fn, mode='rb'), DO_DATAMASK=False, GET_ONLY_DATASETMASK=True, R_READ_MODE='r', OUTDIR=None) for r_fn in AWS_DATA_DICT['RASTER_LIST'][25000:25005]]

# Build a footprint database geodataframe from all individual raster footprints
footprint_gdf = footprintlib.build_footprint_db(f_gdf_lst, TO_GCS=False, WRITE_GPKG=False, OUT_F_NAME=None, OUT_LYR_NAME=AWS_DATA_DICT['BUCKET'])
footprint_gdf['s3_path'] = 's3://' +  footprint_gdf['path'] + '/' + footprint_gdf['file']

footprint_gdf.to_file(outprint_fn, driver='GPKG')
# Out:
# Building GDF from list...
# CPU times: user 247 ms, sys: 33.6 ms, total: 280 ms
# Wall time: 9.12 s

# %%
outprint_fn
# Out:
# '/projects/my-public-bucket/databank/footprints/footprint_alsgedi_global_v6_float_.gpkg'

# %%
footprint_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c8338a325611c32a4e8379e23ce41d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c8338a325611c32a4e8379e23ce41d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c8338a325611c32a4e8379e23ce41d7 = L.map(
#                 &quot;map_0c8338a325611c32a4e8379e23ce41d7&quot;,
#                 {
#                     center: [69.15682062888456, 177.1875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0c8338a325611c32a4e8379e23ce41d7);
#
#
#
#
#
#             var tile_layer_af36530fe1b26678deef67936af9f8ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_af36530fe1b26678deef67936af9f8ed.addTo(map_0c8338a325611c32a4e8379e23ce41d7);
#
#
#             map_0c8338a325611c32a4e8379e23ce41d7.fitBounds(
#                 [[68.65655498475736, 175.78125], [69.65708627301176, 178.59375]],
#                 {}
#             );
#
#
#         function geo_json_54066c2c62d71a4a635a582c71b8b01f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_54066c2c62d71a4a635a582c71b8b01f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_54066c2c62d71a4a635a582c71b8b01f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_54066c2c62d71a4a635a582c71b8b01f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_54066c2c62d71a4a635a582c71b8b01f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_54066c2c62d71a4a635a582c71b8b01f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_54066c2c62d71a4a635a582c71b8b01f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_54066c2c62d71a4a635a582c71b8b01f = L.geoJson(null, {
#                 onEachFeature: geo_json_54066c2c62d71a4a635a582c71b8b01f_onEachFeature,
#
#                 style: geo_json_54066c2c62d71a4a635a582c71b8b01f_styler,
#                 pointToLayer: geo_json_54066c2c62d71a4a635a582c71b8b01f_pointToLayer,
#         });
#
#         function geo_json_54066c2c62d71a4a635a582c71b8b01f_add (data) {
#             geo_json_54066c2c62d71a4a635a582c71b8b01f
#                 .addData(data);
#         }
#             geo_json_54066c2c62d71a4a635a582c71b8b01f_add({&quot;bbox&quot;: [175.78125, 68.65655498475736, 178.59375, 69.65708627301176], &quot;features&quot;: [{&quot;bbox&quot;: [176.48437499999997, 68.9110048456202, 177.1875, 69.16255790810501], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[177.1875, 68.9110048456202], [177.1875, 69.16255790810501], [176.48437499999997, 69.16255790810501], [176.48437499999997, 68.9110048456202], [177.1875, 68.9110048456202]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;area_ha&quot;: 612643.0367849049, &quot;area_km2&quot;: 6126.430367849049, &quot;file&quot;: &quot;113331231.tif&quot;, &quot;footprint_name&quot;: null, &quot;path&quot;: &quot;dataforgood-fb-data/forests/v1/alsgedi_global_v6_float/chm&quot;, &quot;s3_path&quot;: &quot;s3://da

# %%
footprint_gdf.head()
# Out:
#             file                                           geometry  \
# 0  001311332.tif  POLYGON ((-10097025.688 16906647.664, -1009702...
# 1  001311333.tif  POLYGON ((-10018754.171 16906647.664, -1001875...
# 2  001313101.tif  POLYGON ((-10175297.205 16828376.147, -1017529...
# 3  001313103.tif  POLYGON ((-10175297.205 16750104.630, -1017529...
# 4  001313110.tif  POLYGON ((-10097025.688 16828376.147, -1009702...
#
#   footprint_name                                               path  \
# 0           None  dataforgood-fb-data/forests/v1/alsgedi_global_...
# 1           None  dataforgood-fb-data/forests/v1/alsgedi_global_...
# 2           None  dataforgood-fb-data/forests/v1/alsgedi_global_...
# 3           None  dataforgood-fb-data/forests/v1/alsgedi_global_...
# 4           None  dataforgood-fb-data/forests/v1/alsgedi_global_...
#
#       area_km2        area_ha  \
# 0  6126.430368  612643.036785
# 1  6126.430368  612643.036785
# 2  6126.430368  612643.036785
# 3  6126.430368  612643.036785
# 4  6126.430368  612643.036785
#
#                                              s3_path
# 0  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...
# 1  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...
# 2  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...
# 3  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...
# 4  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...

# %% [markdown]
# #### 1-off manual footprint of Meta tiles (n>56k) using info returned from a footprint of the first 5

# %%
tiles_fn = [f for f in AWS_DATA_DICT['FILES_LIST'] if '.geojson' in f][0]
tiles_gdf = gpd.read_file(s3.open(tiles_fn, mode = 'r') )
tiles_gdf['file'] = tiles_gdf.tile + '.tif'
tiles_gdf['footprint_name'] = None
tiles_gdf['path'] = 'dataforgood-fb-data/forests/v1/alsgedi_global_v6_float/chm'
tiles_gdf['area_km2'] = None
tiles_gdf['area_ha'] = 	None
tiles_gdf['s3_path'] = 's3://' + tiles_gdf.path + '/' + tiles_gdf.tile + '.tif'  
tiles_gdf.to_file('/projects/my-public-bucket/databank/footprints/footprint_meta_alsgedi_global_v6_float_.gpkg')

# %%
tiles_gdf.head()
# Out:
#         tile                                           geometry  \
# 0  023013213  POLYGON ((-115.31250 33.13755, -115.31250 33.7...
# 1  021210020  POLYGON ((-123.04688 54.57206, -123.04688 54.9...
# 2  130122211  POLYGON ((115.31250 56.94497, 115.31250 57.326...
# 3  121022223  POLYGON ((46.40625 55.77657, 46.40625 56.17002...
# 4  310111000  POLYGON ((130.07812 -0.70311, 130.07812 0.0000...
#
#             file footprint_name  \
# 0  023013213.tif           None
# 1  021210020.tif           None
# 2  130122211.tif           None
# 3  121022223.tif           None
# 4  310111000.tif           None
#
#                                                 path area_km2 area_ha  \
# 0  dataforgood-fb-data/forests/v1/alsgedi_global_...     None    None
# 1  dataforgood-fb-data/forests/v1/alsgedi_global_...     None    None
# 2  dataforgood-fb-data/forests/v1/alsgedi_global_...     None    None
# 3  dataforgood-fb-data/forests/v1/alsgedi_global_...     None    None
# 4  dataforgood-fb-data/forests/v1/alsgedi_global_...     None    None
#
#                                              s3_path
# 0  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...
# 1  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...
# 2  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...
# 3  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...
# 4  s3://dataforgood-fb-data/forests/v1/alsgedi_gl...

# %% [markdown]
# ## Make a full footprint
# `full` boreal-tcc-unclipped (main + supplemental)

# %%
footprint_2020_boreal_tcc_unclipped = pd.concat([gpd.read_file(f).to_crs(4326)[['s3_path','geometry']] for f in glob.glob(f'/projects/my-public-bucket/databank/footprints/footprint*boreal-tcc-unclipped*{YEAR_TCC}..gpkg')])

# %%
footprint_2020_boreal_tcc_unclipped.to_file(f'/projects/shared-buckets/montesano/databank/footprints/footprint_boreal-tcc-unclipped_y{YEAR_TCC}._full.gpkg')

# %%
boreal_tiles = gpd.read_file('/projects/shared-buckets/montesano/databank/boreal_tiles_v004_model_ready.gpkg')

# %%
m = boreal_tiles.explore(color='red')
footprint_2020_boreal_tcc_unclipped.cx[90:110, 30:75].explore(m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f811128c75460670f37ecb41610ec2cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f811128c75460670f37ecb41610ec2cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f811128c75460670f37ecb41610ec2cb = L.map(
#                 &quot;map_f811128c75460670f37ecb41610ec2cb&quot;,
#                 {
#                     center: [57.16882601566166, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f811128c75460670f37ecb41610ec2cb);
#
#
#
#
#
#             var tile_layer_04fc115a87f4c5587c4a938c3acbd83a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_04fc115a87f4c5587c4a938c3acbd83a.addTo(map_f811128c75460670f37ecb41610ec2cb);
#
#
#             map_f811128c75460670f37ecb41610ec2cb.fitBounds(
#                 [[35.80632446895021, -179.99999], [78.53132756237311, 179.99999]],
#                 {}
#             );
#
#
#         function geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_95ff6e926c53c7ad77fb72ce9ad2a032.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_95ff6e926c53c7ad77fb72ce9ad2a032 = L.geoJson(null, {
#                 onEachFeature: geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_onEachFeature,
#
#                 style: geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_styler,
#                 pointToLayer: geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_pointToLayer,
#         });
#
#         function geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_add (data) {
#             geo_json_95ff6e926c53c7ad77fb72ce9ad2a032
#                 .addData(data);
#         }
#             geo_json_95ff6e926c53c7ad77fb72ce9ad2a032_add({&quot;bbox&quot;: [-179.99999, 35.80632446895021, 179.99999, 78.53132756237311], &quot;features&quot;: [{&quot;bbox&quot;: [6.672362303301861, 56.48186687643973, 8.748942733447695,

# %% [markdown]
# ### Look at a tile

# %%
TILE_NUM= 1840
footprint_2020_boreal_tcc_unclipped_SUBSET = gpd.overlay(boreal_tiles[boreal_tiles.tile_num == TILE_NUM].to_crs(4326), footprint_2020_boreal_tcc_unclipped.cx[90:110, 65:75], how='intersection')
footprint_2020_boreal_tcc_unclipped_SUBSET.to_file(f'/projects/my-public-bucket/local_output/tmp_{TILE_NUM}.gpkg', driver='GPKG')

# %%
m = boreal_tiles[boreal_tiles.tile_num == TILE_NUM].explore(color='red')
footprint_2020_boreal_tcc_unclipped_SUBSET.explore(m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e68e59296ad4cc89315d23324151df9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e68e59296ad4cc89315d23324151df9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e68e59296ad4cc89315d23324151df9 = L.map(
#                 &quot;map_4e68e59296ad4cc89315d23324151df9&quot;,
#                 {
#                     center: [69.76317620163547, 102.0579783740952],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4e68e59296ad4cc89315d23324151df9);
#
#
#
#
#
#             var tile_layer_b5a0830d479c4317d641d314d739cb7f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b5a0830d479c4317d641d314d739cb7f.addTo(map_4e68e59296ad4cc89315d23324151df9);
#
#
#             map_4e68e59296ad4cc89315d23324151df9.fitBounds(
#                 [[69.23292148370352, 100.5232299519198], [70.29343091956741, 103.5927267962706]],
#                 {}
#             );
#
#
#         function geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d = L.geoJson(null, {
#                 onEachFeature: geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_onEachFeature,
#
#                 style: geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_styler,
#                 pointToLayer: geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_pointToLayer,
#         });
#
#         function geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_add (data) {
#             geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d
#                 .addData(data);
#         }
#             geo_json_fb9f1628fac97e29e4cb7ee39a44ec9d_add({&quot;bbox&quot;: [100.5232299519198, 69.23292148370352, 103.5927267962706, 70.29343091956741], &quot;features&quot;: [{&quot;bbox&quot;: [100.523229951

# %% [markdown]
# ###  Test mosaic (using `build_stack()`) with files of different input projections

# %%
# TerraPulse TCC 2020
BUILD_STACK_DICT_TCC2020 = {
            'INDEX_URL': 'https://maap-ops-workspace.s3.amazonaws.com/shared/montesano/databank/boreal_tiles_v004.gpkg',
            'INDEX_FN': 'boreal_tiles_v004.gpkg',
            'ID_COL_NAME': 'tile_num',
            'TILE_NUM':TILE_NUM,
            'INDEX_LYR': 'boreal_tiles_v004',
            'COVAR_SRC_NAME': 'tcc2020', # Change to TCC_TP_2020?
            # Worldcover data is accessed via its footprint, with a 's3_path' col identifying the s3 locations of each tile
            'BANDNAMES_LIST': 'tcc2020',
            'COVAR_TILE_URL': f'https://maap-ops-workspace.s3.amazonaws.com/shared/montesano/local_output/tmp_{TILE_NUM}.gpkg', 
            'COVAR_TILE_FN':  f'/projects/shared-buckets/montesano//local_output/tmp_{TILE_NUM}.gpkg',
            'IN_COVAR_S3_COL': 's3_path',
            'OUTDIR': '/projects/my-public-bucket/local_output/build_stack_tcc2020',
            'NODATA_VAL': 255,
            'TILE_BUFFER_M': 0,
            'OUTPUT_CLIP_COG_FN':'',
            'CREDENTIALS_FN': None
        }
BUILD_STACK_DICT = BUILD_STACK_DICT_TCC2020

# %%
# INDEX clip shapes should be in equal area
# COVAR_TILE_FN tiles (of raster COGs) should be in 4326
args = f"\
    --in_tile_fn /projects/shared-buckets/montesano/databank/boreal_tiles_v004.gpkg \
    --in_tile_id_col {BUILD_STACK_DICT['ID_COL_NAME']} \
    --in_tile_num {BUILD_STACK_DICT['TILE_NUM']} \
    --tile_buffer_m {BUILD_STACK_DICT['TILE_BUFFER_M']} \
    --in_tile_layer {BUILD_STACK_DICT['INDEX_LYR']} \
    -o {BUILD_STACK_DICT['OUTDIR']} \
    --covar_src_name {BUILD_STACK_DICT['COVAR_SRC_NAME']} \
    --bandnames_list {BUILD_STACK_DICT['BANDNAMES_LIST']} \
    --covar_tile_fn {BUILD_STACK_DICT['COVAR_TILE_FN']} \
    --in_covar_s3_col {BUILD_STACK_DICT['IN_COVAR_S3_COL']} \
    --input_nodata_value {BUILD_STACK_DICT['NODATA_VAL']}"

if 'dem' in BUILD_STACK_DICT['COVAR_TILE_FN']:
    args += " --shape 3000 --clip" # for topo
else:
    args += " --topo_off --shape 3000 --clip" # for not topo

print(args)

BUILD_STACK_DICT['BANDNAMES_LIST']
# Out:
#     --in_tile_fn /projects/shared-buckets/montesano/databank/boreal_tiles_v004.gpkg     --in_tile_id_col tile_num     --in_tile_num 1840     --tile_buffer_m 0     --in_tile_layer boreal_tiles_v004     -o /projects/my-public-bucket/local_output/build_stack_tcc2020     --covar_src_name tcc2020     --bandnames_list tcc2020     --covar_tile_fn /projects/shared-buckets/montesano//local_output/tmp_1840.gpkg     --in_covar_s3_col s3_path     --input_nodata_value 255 --topo_off --shape 3000 --clip
# 'tcc2020'

# %%
# !time /projects/env/above/bin/python /projects/code/icesat2_boreal/lib/build_stack.py $args
# Out:
# ---Running build_stack()---
#
# 51 covariate filename(s) intersecting the 0 m buffered bbox for tile id 1840:
#
# in_bbox: [-2421478.0000000047, 4833304.000000009, -2331478.0000000047, 4923304.000000009]
# Getting output height and width from input shape arg...
# 3000 x 3000
# Band indexes list: [1]
# ['tcc2020']
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1402/v102/h1402v102/h1402v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1403/v101/h1403v101/h1403v101_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1403/v102/h1403v102/h1403v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1404/v101/h1404v101/h1404v101_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1404/v102/h1404v102/h1404v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1405/v099/h1405v099/h1405v099_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1405/v101/h1405v101/h1405v101_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1405/v102/h1405v102/h1405v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1406/v098/h1406v098/h1406v098_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1406/v099/h1406v099/h1406v099_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1406/v100/h1406v100/h1406v100_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1406/v101/h1406v101/h1406v101_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1406/v102/h1406v102/h1406v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1407/v098/h1407v098/h1407v098_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1407/v099/h1407v099/h1407v099_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1407/v100/h1407v100/h1407v100_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1407/v101/h1407v101/h1407v101_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1407/v102/h1407v102/h1407v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1407/v103/h1407v103/h1407v103_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1408/v098/h1408v098/h1408v098_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1408/v099/h1408v099/h1408v099_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1408/v100/h1408v100/h1408v100_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1408/v101/h1408v101/h1408v101_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1408/v102/h1408v102/h1408v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1408/v103/h1408v103/h1408v103_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1409/v099/h1409v099/h1409v099_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1409/v100/h1409v100/h1409v100_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1409/v101/h1409v101/h1409v101_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1409/v102/h1409v102/h1409v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1409/v103/h1409v103/h1409v103_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1410/v101/h1410v101/h1410v101_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1410/v102/h1410v102/h1410v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data-supplemental/h1411/v102/h1411v102/h1411v102_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h1000/v094/h1000v094/h1000v094_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h1000/v095/h1000v095/h1000v095_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h1001/v094/h1001v094/h1001v094_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h1001/v095/h1001v095/h1001v095_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h1001/v096/h1001v096/h1001v096_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h1002/v095/h1002v095/h1002v095_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h1002/v096/h1002v096/h1002v096_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h995/v091/h995v091/h995v091_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h995/v092/h995v092/h995v092_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h996/v092/h996v092/h996v092_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h996/v093/h996v093/h996v093_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h997/v092/h997v092/h997v092_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h997/v093/h997v093/h997v093_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h998/v092/h998v092/h998v092_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h998/v093/h998v093/h998v093_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h998/v094/h998v094/h998v094_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h999/v093/h999v093/h999v093_y2020_dat.tif
# s3://terrapulse-pub-data/boreal-tcc-unclipped/data/h999/v094/h999v094/h999v094_y2020_dat.tif
#  ~~Entering memory management mode to complete run on 32 GB worker~~
# Reducing threads to 5 since # files > 30...
# /projects/env/above/lib/python3.9/site-packages/rio_tiler/io/rasterio.py:130: NoOverviewWarning: The dataset has no Overviews. rio-tiler performances might be impacted.
#   warnings.warn(
# Stack (mosaic) shape: (1, 3000, 3000)
# Writing stack as cloud-optimized geotiff: /projects/my-public-bucket/local_output/build_stack_tcc2020/tcc2020_1840_cog.tif
# Clipping to feature polygon...
# Orig stack shape:		 (1, 3000, 3000)
# Output resolution:		 (30, 30)
# Clipping (in memory) with geom...
# Writing img to memory...
# /projects/code/icesat2_boreal/lib/build_stack.py:211: RasterioDeprecationWarning: Source dataset should be opened in read-only mode. Use of datasets opened in modes other than 'r' will be disallowed in a future version.
#   write_cog(mosaic,
# {'driver': 'VRT', 'dtype': 'uint8', 'nodata': 255, 'width': 3000, 'height': 3000, 'count': 1, 'crs': CRS.from_wkt('PROJCS["unnamed",GEOGCS["GRS 1980(IUGG, 1980)",DATUM["unknown",SPHEROID["GRS80",6378137,298.257222101],TOWGS84[0,0,0,0,0,0,0]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["standard_parallel_1",50],PARAMETER["standard_parallel_2",70],PARAMETER["latitude_of_center",40],PARAMETER["longitude_of_center",180],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["Meter",1],AXIS["Easting",EAST],AXIS["Northing",NORTH]]'), 'transform': Affine(30.0, 0.0, -2421478.0000000047,
#        0.0, -30.0, 4923304.000000009), 'blockxsize': 512, 'blockysize': 128, 'tiled': True}
# Reading input: <open WarpedVRT name='WarpedVRT(/vsimem/f4935da6-4ac6-41f0-8be0-4fc61ed461a2/f4935da6-4ac6-41f0-8be0-4fc61ed461a2.tif)' mode='r'>
#   [####################################]  100%
# Adding overviews...
# Updating dataset tags...
# Writing output to: /projects/my-public-bucket/local_output/build_stack_tcc2020/tcc2020_1840_cog.tif
# Image written to disk:		 /projects/my-public-bucket/local_output/build_stack_tcc2020/tcc2020_1840_cog.tif
#
# real	1m39.638s
# user	1m0.030s
# sys	0m9.586s

# %% [markdown]
# ### this was moved to build_stack

# %%
def show_raster(s3_path, MAX_VALID=100, VMAX=100, cmap='RdYlGn', title=''):
    
    ''' Show a raster on s3 or local with a colormap '''
    
    import matplotlib.pyplot as plt
    import rasterio
    from rasterio.plot import show, show_hist
    import numpy as np
    import numpy.ma as ma
    
    fig, ax = plt.subplots(figsize=(5, 5))
    
    with rasterio.env.Env(AWS_NO_SIGN_REQUEST = 'YES'):
        
        with rasterio.open(s3_path) as src:
            print(src.nodata)
            arr=src.read(1, masked=True)
            arr = ma.masked_where(arr>MAX_VALID, ma.masked_where(arr==0, arr))
            #show(arr, cmap=cmap)
            # use imshow so that we have something to map the colorbar to
            image_hidden = ax.imshow(arr, cmap=cmap)

            # plot on the same axis with rio.plot.show
            image = rio.plot.show(arr, 
                                  transform=src.transform, 
                                  ax=ax, 
                                  cmap=cmap, vmax=VMAX)
            
            ax.set_title(title)

            # add colorbar using the now hidden image
            fig.colorbar(image_hidden, ax=ax, shrink=0.8)

# %%
import build_stack
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import build_stack
#
# ModuleNotFoundError: No module named 'build_stack'

# %%
s3_url = footprint_2020_boreal_tcc_unclipped_SUBSET.s3_path.to_list()[5]
local_url = f'/projects/my-public-bucket/local_output/build_stack_tcc2020/tcc2020_{TILE_NUM}_cog.tif'

show_raster(local_url, cmap='magma', VMAX=20, title=f'Mosaic of TerraPulse tree canopy cover (%)\nfor boreal tile {TILE_NUM}')
# Out:
# None

# %% [markdown]
# ### Map footprints

# %%
# load natural earth low res shapefile
ne = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# get AOI geometry
country = 'Canada'
geom = ne[ne.name == country].iloc[0].geometry

# get tiles intersecting AOI
tiles = footprint_gdf[footprint_gdf.intersects(geom)]

ax = tiles.to_crs(3857).boundary.plot(color='red')
ax = ne[ne.name == country].boundary.plot(ax=ax, color='black')
ctx.add_basemap(ax)

# %%
import s3fs

# %%
fn = 's3://maap-ops-workspace/lduncanson/dps_output/run_boreal_biomass_map/boreal_agb_2024_v6/2024/10/03/22/51/01/462827/boreal_agb_202410031728020934_041807.tif'

# %%
s3 = s3fs.S3FileSystem(anon=True)

# %%
s3.download(fn, '/projects/my-public-bucket/tmp')
# Out:
# [None]
